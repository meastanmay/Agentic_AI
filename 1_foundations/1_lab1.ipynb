# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
nvidia_api_key = os.getenv('nvidia_qwen_instruct_api_key')
nvidia_base_url = os.getenv('nvidia_base_url')
if nvidia_api_key:
    print(f"NVIDIA API Key exists and begins {nvidia_api_key[:8]}")
else:
    print("NVIDIA API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# NVIDIA API Key exists and begins nvapi-JC

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

nvidia_client = OpenAI(
    base_url=nvidia_base_url,
    api_key=nvidia_api_key
)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = nvidia_client.chat.completions.create(
    model="qwen/qwen3-next-80b-a3b-instruct",
    messages=messages,
    temperature=0.6,
    top_p=0.7,
    max_tokens=4096,
    stream=False
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = nvidia_client.chat.completions.create(
    model="qwen/qwen3-next-80b-a3b-instruct",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If a clock loses 12 minutes every hour and another gains 8 minutes every hour, both starting at 12:00 noon, after how many real hours will they next show the same time simultaneously, and what time will each clock display at that moment?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = nvidia_client.chat.completions.create(
    model="qwen/qwen3-next-80b-a3b-instruct",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# We are given two clocks:
#
# - **Clock A**: Loses 12 minutes every hour → so it runs **slow**.
# - **Clock B**: Gains 8 minutes every hour → so it runs **fast**.
#
# Both start at **12:00 noon** (real time).
#
# We are to find:
#
# 1. After how many **real hours** will they **next show the same time simultaneously**?
# 2. What time will each clock display at that moment?
#
# ---
#
# ### Step 1: Understand how each clock behaves
#
# Let’s denote **t** as the number of **real hours** that have passed since 12:00 noon.
#
# - **Clock A (slow)**: Loses 12 min per real hour → so in t real hours, it only advances by:
#   $$
#   t - \frac{12}{60}t = t - 0.2t = 0.8t \text{ hours}
#   $$
#   So Clock A shows: **0.8t hours** after 12:00.
#
# - **Clock B (fast)**: Gains 8 min per real hour → so in t real hours, it advances by:
#   $$
#   t + \frac{8}{60}t = t + \frac{2}{15}t = \frac{17}{15}t \text{ hours}
#   $$
#   So Clock B shows: **(17/15)t hours** after 12:00.
#
# ---
#
# ### Step 2: When do they show the same time?
#
# We want the times shown by the two clocks to be **equal modulo 12 hours**, because clocks are 12-hour cycles.
#
# That is, the **difference** between the two clock readings should be a multiple of 12 hours.
#
# Let’s compute the difference in displayed time:
#
# $$
# \text{Clock B} - \text{Clock A} = \frac{17}{15}t - 0.8t
# $$
#
# Convert 0.8 to fraction: $0.8 = \frac{4}{5} = \frac{12}{15}$
#
# So:
#
# $$
# \frac{17}{15}t - \frac{12}{15}t = \frac{5}{15}t = \frac{1}{3}t
# $$
#
# So the difference between Clock B and Clock A is $\frac{1}{3}t$ hours.
#
# We want this difference to be a **multiple of 12 hours**, because the clocks are analog (12-hour cycle), so when the difference is 12, 24, 36, ... hours, they will show the same time again.
#
# So set:
#
# $$
# \frac{1}{3}t = 12k \quad \text{for some integer } k
# $$
#
# We want the **smallest positive t**, so take $k = 1$:
#
# $$
# \frac{1}{3}t = 12 \Rightarrow t = 36 \text{ real hours}
# $$
#
# ✅ So after **36 real hours**, the two clocks will show the same time again.
#
# ---
#
# ### Step 3: What time does each clock show at t = 36 real hours?
#
# #### Clock A (slow): shows 0.8t hours
#
# $$
# 0.8 \times 36 = 28.8 \text{ hours}
# $$
#
# Convert 28.8 hours to days and hours:
#
# - 28.8 hours = 24 + 4.8 hours → so **4.8 hours** past 12:00 noon (on the next day)
#
# 4.8 hours = 4 hours + 0.8×60 = 48 minutes → so **4:48**
#
# But since it's 28.8 hours from start, and clocks are 12-hour cycles, we take modulo 12.
#
# Wait — **important**: Clocks are 12-hour analog clocks, so we need to reduce the displayed time **modulo 12 hours**.
#
# So for Clock A: 28.8 hours mod 12
#
# Compute:
#
# 28.8 ÷ 12 = 2.4 → 2 full cycles (24 hours), remainder = 4.8 hours
#
# So Clock A shows: **4:48**
#
# #### Clock B (fast): shows (17/15)t = (17/15)*36
#
# $$
# \frac{17}{15} \times 36 = 17 \times \frac{36}{15} = 17 \times 2.4 = 40.8 \text{ hours}
# $$
#
# Now take 40.8 mod 12:
#
# 40.8 ÷ 12 = 3.4 → 3 full cycles (36 hours), remainder = 4.8 hours
#
# So Clock B also shows: **4:48**
#
# ✅ Both show **4:48**!
#
# ---
#
# ### Final Answer:
#
# - **After 36 real hours**, the two clocks will next show the same time.
# - At that moment, **both clocks display 4:48**.
#
# ---
#
# ### Bonus: Why not earlier?
#
# We assumed the first time they match is when the difference is exactly 12 hours. Could it be 0 hours? That would mean they show the same time immediately — but at t=0, they both show 12:00, but the question asks for the **next** time they show the same time.
#
# So we need the **next** time after t=0.
#
# Is there a smaller t where difference is 12k for k=1? We took k=1 → t=36.
#
# What if k=0? Then t=0 — that’s the start, so we discard.
#
# Next possible k=1 → t=36.
#
# Could the difference be 24 hours? Then t=72, which is later.
#
# So **36 hours** is the first time after start they match again.
#
# ✅ Confirmed.
#
# ---
#
# ### ✅ Final Answer:
#
# **After 36 real hours, both clocks will next show the same time, which is 4:48.**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# We are given two clocks:
#
# - **Clock A**: Loses 12 minutes every hour → so it runs **slow**.
# - **Clock B**: Gains 8 minutes every hour → so it runs **fast**.
#
# Both start at **12:00 noon** (real time).
#
# We are to find:
#
# 1. After how many **real hours** will they **next show the same time simultaneously**?
# 2. What time will each clock display at that moment?
#
# ---
#
# ### Step 1: Understand how each clock behaves
#
# Let’s denote **t** as the number of **real hours** that have passed since 12:00 noon.
#
# - **Clock A (slow)**: Loses 12 min per real hour → so in t real hours, it only advances by:
#   $$
#   t - \frac{12}{60}t = t - 0.2t = 0.8t \text{ hours}
#   $$
#   So Clock A shows: **0.8t hours** after 12:00.
#
# - **Clock B (fast)**: Gains 8 min per real hour → so in t real hours, it advances by:
#   $$
#   t + \frac{8}{60}t = t + \frac{2}{15}t = \frac{17}{15}t \text{ hours}
#   $$
#   So Clock B shows: **(17/15)t hours** after 12:00.
#
# ---
#
# ### Step 2: When do they show the same time?
#
# We want the times shown by the two clocks to be **equal modulo 12 hours**, because clocks are 12-hour cycles.
#
# That is, the **difference** between the two clock readings should be a multiple of 12 hours.
#
# Let’s compute the difference in displayed time:
#
# $$
# \text{Clock B} - \text{Clock A} = \frac{17}{15}t - 0.8t
# $$
#
# Convert 0.8 to fraction: $0.8 = \frac{4}{5} = \frac{12}{15}$
#
# So:
#
# $$
# \frac{17}{15}t - \frac{12}{15}t = \frac{5}{15}t = \frac{1}{3}t
# $$
#
# So the difference between Clock B and Clock A is $\frac{1}{3}t$ hours.
#
# We want this difference to be a **multiple of 12 hours**, because the clocks are analog (12-hour cycle), so when the difference is 12, 24, 36, ... hours, they will show the same time again.
#
# So set:
#
# $$
# \frac{1}{3}t = 12k \quad \text{for some integer } k
# $$
#
# We want the **smallest positive t**, so take $k = 1$:
#
# $$
# \frac{1}{3}t = 12 \Rightarrow t = 36 \text{ real hours}
# $$
#
# ✅ So after **36 real hours**, the two clocks will show the same time again.
#
# ---
#
# ### Step 3: What time does each clock show at t = 36 real hours?
#
# #### Clock A (slow): shows 0.8t hours
#
# $$
# 0.8 \times 36 = 28.8 \text{ hours}
# $$
#
# Convert 28.8 hours to days and hours:
#
# - 28.8 hours = 24 + 4.8 hours → so **4.8 hours** past 12:00 noon (on the next day)
#
# 4.8 hours = 4 hours + 0.8×60 = 48 minutes → so **4:48**
#
# But since it's 28.8 hours from start, and clocks are 12-hour cycles, we take modulo 12.
#
# Wait — **important**: Clocks are 12-hour analog clocks, so we need to reduce the displayed time **modulo 12 hours**.
#
# So for Clock A: 28.8 hours mod 12
#
# Compute:
#
# 28.8 ÷ 12 = 2.4 → 2 full cycles (24 hours), remainder = 4.8 hours
#
# So Clock A shows: **4:48**
#
# #### Clock B (fast): shows (17/15)t = (17/15)*36
#
# $$
# \frac{17}{15} \times 36 = 17 \times \frac{36}{15} = 17 \times 2.4 = 40.8 \text{ hours}
# $$
#
# Now take 40.8 mod 12:
#
# 40.8 ÷ 12 = 3.4 → 3 full cycles (36 hours), remainder = 4.8 hours
#
# So Clock B also shows: **4:48**
#
# ✅ Both show **4:48**!
#
# ---
#
# ### Final Answer:
#
# - **After 36 real hours**, the two clocks will next show the same time.
# - At that moment, **both clocks display 4:48**.
#
# ---
#
# ### Bonus: Why not earlier?
#
# We assumed the first time they match is when the difference is exactly 12 hours. Could it be 0 hours? That would mean they show the same time immediately — but at t=0, they both show 12:00, but the question asks for the **next** time they show the same time.
#
# So we need the **next** time after t=0.
#
# Is there a smaller t where difference is 12k for k=1? We took k=1 → t=36.
#
# What if k=0? Then t=0 — that’s the start, so we discard.
#
# Next possible k=1 → t=36.
#
# Could the difference be 24 hours? Then t=72, which is later.
#
# So **36 hours** is the first time after start they match again.
#
# ✅ Confirmed.
#
# ---
#
# ### ✅ Final Answer:
#
# **After 36 real hours, both clocks will next show the same time, which is 4:48.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick up a business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response =nvidia_client.chat.completions.create(
    model="qwen/qwen3-next-80b-a3b-instruct",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message

# %%
display(Markdown(business_idea))
# Out:
# A high-potential business area worth exploring for an **Agentic AI opportunity** is:
# **Automated End-to-End Customer Success Management for SaaS Companies**
#
# ---
#
# ### **Why This Area?**
#
# SaaS companies face intense churn pressure and rely heavily on customer success (CS) teams to drive retention, upsells, and advocacy. However, CS teams are often overwhelmed by:
#
# - High customer volume (100s–1000s of accounts)
# - Manual monitoring of usage, support tickets, and sentiment
# - Delayed interventions
# - Inconsistent communication across teams (sales, support, product)
#
# This creates a ripe opportunity for **Agentic AI** — autonomous, goal-driven AI agents that can proactively manage customer relationships at scale.
#
# ---
#
# ### **Agentic AI Opportunity: “Customer Success Autopilot”**
#
# Imagine an AI agent system composed of **specialized sub-agents** working collaboratively:
#
# | Sub-Agent | Function |
# |----------|----------|
# | **Monitor Agent** | Continuously ingests data: product usage logs, support ticket sentiment, NPS surveys, billing status, email/Slack interactions. |
# | **Diagnose Agent** | Uses ML to detect early churn signals (e.g., declining feature usage, repeated support tickets, payment failures). |
# | **Engage Agent** | Proactively reaches out via personalized email, in-app message, or video call (using synthetic voice/video) to offer help, tips, or check-ins. |
# | **Resolve Agent** | If a ticket is detected, auto-triages and resolves common issues (e.g., password reset, billing clarification) using integrations with Zendesk, Intercom, etc. |
# | **Upsell Agent** | Identifies usage patterns indicating readiness for upgrade (e.g., hitting usage limits) and recommends tailored plans with contextual justification. |
# | **Feedback Agent** | Collects qualitative feedback post-interaction and feeds insights to product teams. |
#
# ---
#
# ### **Why Agentic AI (Not Just Chatbots or Automation)?**
#
# - **Autonomy**: Agents make decisions without human hand-holding (e.g., “This customer is at 85% churn risk — trigger a call now.”)
# - **Goal-Driven**: Each agent optimizes for outcomes: reduce churn by 20%, increase expansion revenue by 15%.
# - **Collaborative**: Agents delegate tasks, share context, and escalate only when needed.
# - **Adaptive**: Learns from outcomes — if a message style fails, it tweaks tone and timing.
#
# ---
#
# ### **Market Size & Traction**
#
# - Global SaaS market: **$700B+ by 2030** (Statista)
# - Customer success software market: **$15B+** (Gartner)
# - 70% of SaaS churn is preventable — but most companies lack resources to act on signals in time.
#
# Startups like **Gainsight** and **Totango** offer tools — but none yet deploy **autonomous, goal-driven AI agents** to own the entire lifecycle.
#
# ---
#
# ### **Go-to-Market Strategy**
#
# 1. **Pilot with mid-market SaaS** (500–5,000 customers) — low friction, high ROI potential.
# 2. **Integrate with existing stack**: Salesforce, HubSpot, Mixpanel, Intercom.
# 3. **Pricing**: % of saved ARR or % of upsell revenue generated.
# 4. **Differentiator**: “We don’t just alert you — we act for you.”
#
# ---
#
# ### **Potential Impact**
#
# - **Reduce churn by 20–40%**
# - **Increase expansion revenue by 15–30%**
# - **Cut CS team workload by 50%**
# - **Turn customers into advocates** via hyper-personalized, timely engagement
#
# ---
#
# ### **Bonus: Future Expansion**
#
# - Extend to **B2B enterprise onboarding** (AI onboarding coaches)
# - Integrate with **AI sales reps** for seamless handoff from sales to CS
# - Build **customer health scoring** as a standalone AI product
#
# ---
#
# This isn’t just automation — it’s **autonomous customer stewardship**.
# Agentic AI can turn Customer Success from a reactive cost center into a proactive, revenue-driving engine.
#
# **This is a $10B+ opportunity waiting for the right agent architecture.**
